# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/adl-cw/work/dcase.py --epochs 1
# Out:
# Using cpu device.
# Computing norm.
# Done.
# Using proir norm.
# Total number of classes/categories: 15
# Writing logs to logs/CNN_bn_bs=64_lr=0.0005_run_0
# Epoch 1/1
# -------------------------------
# loss: 2.823129, [    0/11700], batch=  1/183, current_bsize= 64, baccuracy:  4.7%, bclass_accuracy:[100,  0,  0,  0,  0,  0,  0, 33,  0,  0,  0,  0,  0,  0,  0,]
# loss: 2.963276, [   64/11700], batch=  2/183, current_bsize= 64, baccuracy: 21.9%, bclass_accuracy:[  0,100,100,100,  0,  0,  0,  0,  0,  0,  0,  0, 17,  0, 50,]
# loss: 2.144161, [  128/11700], batch=  3/183, current_bsize= 64, baccuracy: 37.5%, bclass_accuracy:[  0, 20,  0,100, 57,  0,  0,  0,  0,  0,  0, 88, 50, 67,  0,]
# loss: 2.566928, [  192/11700], batch=  4/183, current_bsize= 64, baccuracy: 23.4%, bclass_accuracy:[  0, 25,  0, 75, 67,  0,  0,  0,  0,  0, 33, 57,  0, 80,  0,]
# ...
